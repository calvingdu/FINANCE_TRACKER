# %%
from src.plugins.mongoDB.mongodb_hook import MongoDBHook
from prefect.filesystems import LocalFileSystem

mdb = MongoDBHook()

mdb.extract_df()
# Out:
#             account       date                           description  amount  \
# 0    BMO_MASTERCARD 2023-02-27   TRSF FROM/DE ACCT/CPT 2503-XXXX-940  -90.18
# 1    BMO_MASTERCARD 2023-03-01             HARVEY'S #2729 TORONTO ON   13.54
# 2    BMO_MASTERCARD 2023-03-04  DOMINOS PIZZA #39032 604-733-2118 BC  101.66
# 3    BMO_MASTERCARD 2023-03-04  DOMINOS PIZZA #39032 604-733-2118 BC  100.14
# 4    BMO_MASTERCARD 2023-03-06             HMART - DUNDAS TORONTO ON    7.72
# ..              ...        ...                                   ...     ...
# 644  BMO_MASTERCARD 2023-04-12            GONG CHA EATONS TORONTO ON    6.67
# 645  BMO_MASTERCARD 2023-04-12                    NYF3244 TORONTO ON    8.13
# 646  BMO_MASTERCARD 2023-04-16      REAL FRUIT BUBBLE TEA TORONTO ON    6.20
# 647  BMO_MASTERCARD 2023-04-17             HMART - DUNDAS TORONTO ON   28.44
# 648  BMO_MASTERCARD 2023-04-19      INDIAN BIRIYANI HOUSE TORONTO ON   18.63
#
#               category
# 0           food_drink
# 1           food_drink
# 2           food_drink
# 3           food_drink
# 4    income_government
# ..                 ...
# 644         food_drink
# 645          bank_fees
# 646         food_drink
# 647         food_drink
# 648         food_drink
#
# [649 rows x 5 columns]

# %%
def func(hi, **kwargs): 
    print(hi)
    print(kwargs['log'])

func(hi = 'hi', log = 'log')
# Out:
# hi
# log
